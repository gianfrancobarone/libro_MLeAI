# %%
import pandas as pd 
data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv") 
data.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", delimiter=';') 
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
#!df -h
#!cat /proc/cpuinfo
#!cat /proc/meminfo.


DPI = 300

#Valori in cm
def cm2inch(*tupl):
    inch = 2.54
    if isinstance(tupl[0], tuple):
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)

#impostazione della dimesione dei font
#plt.rcParams.update({'font.size': 8})

#np.random.seed(10)

#import e gloabals e funzioni
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import Generator, PCG64
# %matplotlib inline

# %%
print(data['quality'].describe())
fs=(cm2inch(12,6))
fig, ax = plt.subplots(figsize = fs, tight_layout = True, dpi = DPI)
ax.hist(data['quality'])
fig.show()
fig.savefig('7.1.png')
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
pd.set_option('display.max_columns', 20)
(data.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#import seaborn as sns

#sns.set(style="ticks", color_codes=True)
#g = sns.pairplot(data, height = 12/2.54, corner= True)
#g.savefig('7.2.png', dpi=300)

# %%
"""import seaborn as sns

iris = sns.load_dataset("iris")
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(iris, height = 12.0/2.54)
g.savefig('7.2.png', dpi=300)"""
# Out:
# 'import seaborn as sns\n\niris = sns.load_dataset("iris")\nsns.set(style="ticks", color_codes=True)\ng = sns.pairplot(iris, height = 12.0/2.54)\ng.savefig(\'7.2.png\', dpi=300)'

# %%
import seaborn as sns

iris = sns.load_dataset("iris")
sns.set(style="ticks", color_codes=True, font_scale = 2)
g = sns.pairplot(iris, height = 12/2.54, corner= True,  hue="species", palette = 'viridis', plot_kws={"s": 290})
g.savefig('7.2.png', dpi=300)

# %%
import seaborn as sns

fs=(cm2inch(12,10))
fig, ax = plt.subplots(1, 1, figsize = fs, tight_layout = True, dpi = DPI)
sns.set(style="ticks", color_codes=True, font_scale = 0.5)
sns.heatmap(data.corr(), cmap='viridis',annot=True, fmt=".2f")
fig.show()
fig.savefig('7.3.png')

# %%
import pandas as pd 

data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", delimiter=';') 
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import matplotlib.gridspec as gridspec
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

xs = list(data['total sulfur dioxide'])
ys = list(data['alcohol'])
zs = list(data['citric acid'])

ss = list(data['quality'])
ss = [1 if x <= 2 else 10 if x <= 5 else 80 if x <= 7 else 160 for x in ss]


fs=(cm2inch(12,10))
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=fs, dpi=300)
ax = Axes3D(fig)

ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.view_init(20, 20)
for px, py, pz, sz in zip(xs, ys, zs, ss):
    ax.scatter(px, py, pz, marker = ".", s = sz*1.5, color = 'b', alpha = 0.15)


ax.set_xlabel('total sulfur dioxide')
ax.set_ylabel('Alcohol')
ax.set_zlabel('citric acid')

fig.show()
fig.savefig('7.4.png')

# %%
from sklearn.preprocessing import minmax_scale

zss = minmax_scale(zs, feature_range=(0, 1), axis=0, copy=True)

fs=(cm2inch(12,10))
fig, ax=plt.subplots(nrows=1, ncols=1, figsize=fs, dpi=300)


for px, py, pz, sz in zip(xs, ys, zss, ss):
    ax.scatter(px, py, marker = ".", s = sz*1.5, color = 'b', alpha = pz)

ax.set_xlabel('total sulfur dioxide')
ax.set_ylabel('Alcohol')

fig.show()
fig.savefig('7.5.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

#scaler = StandardScaler()
scaler = MinMaxScaler()

X = data.iloc[:, :11]
y = data.iloc[:, -1:]

X_s = scaler.fit_transform(X)
pca = decomposition.PCA(n_components=3)
X_t = pca.fit_transform(X_s)

import matplotlib.gridspec as gridspec
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

fs=(cm2inch(12,10))
fig, ax=plt.subplots(nrows=1, ncols=1, figsize=fs, dpi=300)
ax = Axes3D(fig)

ax.view_init(20, -150)
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

for p, sz in zip(X_t, ss):
    if sz == 10: 
      c = 'g'
      a = 0.2
    elif sz == 80: 
      c = 'b'
      a = 0.35
    elif sz == 160: 
      c = 'r'
      a = 0.8
    ax.scatter(p[0], p[1], p[2], marker = ".", s = sz*1.5, color = c, alpha = a)


fig.show()
fig.savefig('7.6.png')

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import decomposition

scaler = StandardScaler()
scaler = MinMaxScaler()

X = data.iloc[:, :11]
y = data.iloc[:, -1:]

X_s = scaler.fit_transform(X)
pca = decomposition.PCA(n_components=2)
X_t = pca.fit_transform(X_s)

fs=(cm2inch(12,10))
fig, ax=plt.subplots(nrows=1, ncols=1, figsize=fs, dpi=300)

for p, sz in zip(X_t, ss):
    if sz == 10: 
      c = 'g'
      a = 0.2
    elif sz == 80: 
      c = 'b'
      a = 0.2
    elif sz == 160: 
      c = 'r'
      a = 0.8
    ax.scatter(p[0], p[1], marker = ".", s = 10, color = c, alpha = 0.5)


fig.show()
fig.savefig('7.6.png')

# %%
from sklearn import manifold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()
scaler = MinMaxScaler()

X_s = scaler.fit_transform(X)
#model = manifold.TSNE(n_components=2, init='pca', random_state=0)
model = manifold.Isomap(n_components=2, n_neighbors=10)
#model = manifold.LocallyLinearEmbedding(n_components=2, n_neighbors=10)
X_t = model.fit_transform(X_s)

X_ns = X
model = manifold.Isomap(n_components=2, n_neighbors=10)
X_tn = model.fit_transform(X_ns)

fs=(cm2inch(12,6))
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=fs, dpi=300)

for p, sz in zip(X_t, ss):
    if sz == 10: 
      c = 'g'
      a = 0.2
    elif sz == 80: 
      c = 'b'
      a = 0.2
    elif sz == 160: 
      c = 'r'
      a = 0.8
    ax[0].scatter(p[0], p[1], marker = ".", s = sz, color = c, alpha = a)

for p, sz in zip(X_tn, ss):
    if sz == 10: 
      c = 'g'
      a = 0.2
    elif sz == 80: 
      c = 'b'
      a = 0.2
    elif sz == 160: 
      c = 'r'
      a = 0.8
    ax[1].scatter(p[0], p[1], marker = ".", s = sz, color = c, alpha = a)


fig.show()
fig.savefig('7.6.png')

# %%
print(data['residual sugar'].describe())
fs=(cm2inch(12,8))
fig, ax = plt.subplots(figsize = fs, tight_layout = True, dpi = DPI)
sns.distplot(data['residual sugar'], hist = False, kde = True,
                 kde_kws = {'linewidth': 1})
fig.show()
fig.savefig('7.7.png')

from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson', standardize=False)
print(data['residual sugar'].shape)

rs_tr = pt.fit_transform(data['residual sugar'].values.reshape(-1,1))                         

fig, ax = plt.subplots(figsize = fs, tight_layout = True, dpi = DPI)
sns.distplot(rs_tr, hist = False, kde = True,
                 kde_kws = {'linewidth': 1})
fig.show()
fig.savefig('7.8.png')
# Out:
# count    1599.000000
# mean        2.538806
# std         1.409928
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# (1599,)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
